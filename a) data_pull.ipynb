# %%
import pandas as pd
from Stocks import Stock

import yaml
import sys
from pathlib import Path

def read_yaml(file_name): 
    with open(file_name) as file:
        yaml_data= yaml.safe_load(file)
    return yaml_data

config = read_yaml('config.yaml')
# config['canadian_etfs_parsed']
canadian_etfs_parsed = config['canadian_etfs_parsed']

# %%
from datetime import datetime, timedelta

yesterday = (datetime.today() - timedelta(days=2)).strftime('%Y-%m-%d')
print(yesterday)
# Out:
# 2025-06-24

# %%
apple = Stock('AAPL', '2021-10-01', yesterday)
apple.ticker_data
# Out:
# data from alpaca
#                Open     High       Low   Close     Volume
# 2021-10-01  141.900  142.920  139.1101  142.65  102369995
# 2021-10-04  141.760  142.210  138.2700  139.14  107234871
# 2021-10-05  139.490  142.240  139.3600  141.11   87278742
# 2021-10-06  139.470  142.150  138.3700  142.00   88503163
# 2021-10-07  143.060  144.215  142.7200  143.29   66148653
# ...             ...      ...       ...     ...        ...
# 2025-06-17  197.200  198.390  195.2100  195.64   38856152
# 2025-06-18  195.940  197.570  195.0700  196.58   45394689
# 2025-06-20  198.235  201.700  196.8550  201.00   96813542
# 2025-06-23  201.625  202.300  198.9600  201.50   55814272
# 2025-06-24  202.590  203.440  200.2000  200.30   54064033
#
# [935 rows x 5 columns]

# %%
import yfinance as yf

# Download historical data for Apple (AAPL)
data = yf.download('VFV.TO', start='2021-10-01', end='2023-03-01')
data
# Out:
# /var/folders/y5/tznhkgh5213_vwg51thdy0x80000gn/T/ipykernel_40467/2625118701.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download('VFV.TO', start='2021-10-01', end='2023-03-01')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open  Volume
# Ticker         VFV.TO     VFV.TO     VFV.TO     VFV.TO  VFV.TO
# Date
# 2021-10-01  93.508301  93.891533  92.243640  93.029262  251200
# 2021-10-04  91.937057  93.144236  91.515501  93.067589  255500
# 2021-10-05  92.943039  93.402912  92.224481  92.358611  115100
# 2021-10-06  93.374176  93.374176  92.195746  92.454423  200000
# 2021-10-07  93.786140  94.629245  93.776558  94.226855  148300
# ...               ...        ...        ...        ...     ...
# 2023-02-22  93.602539  93.972584  93.329866  93.768085  109400
# 2023-02-23  94.001808  94.216047  93.203285  94.216047  121500
# 2023-02-24  93.475945  93.670711  93.086419  93.544111  143600
# 2023-02-27  93.544106  94.274462  93.378560  94.069963  143200
# 2023-02-28  93.748604  94.196563  93.475938  93.592798  165100
#
# [353 rows x 5 columns]

# %%
vfv = Stock('VFV.TO', '2021-10-01', yesterday)
vfv.ticker_data
# Out:
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# [*********************100%***********************]  1 of 1 completed
#                  Price        High         Low        Open  Volume
# 2021-10-01   93.508316   93.891548   92.243655   93.029278  251200
# 2021-10-04   91.937050   93.144229   91.515494   93.067581  255500
# 2021-10-05   92.943031   93.402904   92.224474   92.358604  115100
# 2021-10-06   93.374176   93.374176   92.195746   92.454423  200000
# 2021-10-07   93.786148   94.629253   93.776565   94.226863  148300
# ...                ...         ...         ...         ...     ...
# 2025-06-17  145.139999  145.529999  144.860001  145.110001  154900
# 2025-06-18  145.649994  146.429993  145.199997  145.429993  169900
# 2025-06-19  145.110001  145.500000  144.509995  145.350006  143900
# 2025-06-20  145.740005  146.779999  145.270004  146.440002  201700
# 2025-06-23  147.100006  147.190002  145.589996  146.130005  302100
#
# [935 rows x 5 columns]

# %%
dataframes_list = []

for x in canadian_etfs_parsed: 
    print(x)
    
    temp_data = Stock(x, '2018-03-01', yesterday).ticker_data
    temp_data['Stock_name'] = x
    dataframes_list.append(temp_data)
# Out:
# BXF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CBD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CBH.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CBN.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CBO.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CDZ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CEW.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CGL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CGR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CHB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CIF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CLF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CLG.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CMR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# COW.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CPD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CSD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CUD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CVD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CWW.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CXF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# CYH.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# DLR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# DXM.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ELV.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ETP.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# EUR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FDE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FDV.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FDY.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHC.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHG.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHH.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHM.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHQ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FHU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FIE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FLI.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FSL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FUD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# FXM.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAC.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAJ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HAZ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HBA.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HBB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HBD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HBU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HCA.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEA.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HED.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEJ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEP.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEW.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HEX.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HFD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HFG.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HFP.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HFR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HFT.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HFU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HGD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HGU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HGY.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HHF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HIU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HIX.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HMF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HND.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HNU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HNY.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HOD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HOG.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HOU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HPR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HQD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HQU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HSD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HSL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HSU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUC.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUG.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUM.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUN.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUT.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUV.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HUZ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HVI.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HVU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HXD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HXE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HXF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HXS.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HXT.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HXU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HYI.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HZD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# HZU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ILV.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# KILO.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# MXF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PBD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PBI.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PDC.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PDF.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PFL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PHE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# PHR.TO
# data from alpaca
# ...
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZFL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZFM.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZFS.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZGD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZGI.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZGQ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZHY.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZIC.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZID.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZIN.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZJG.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZJN.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZJO.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZLB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZLC.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZLU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZMI.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZMP.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZMT.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZMU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZPL.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZPR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZPS.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZQQ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZRE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZRR.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZSP.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZST.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZSU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZUB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZUD.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZUE.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZUH.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZUQ.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZUT.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZWA.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZWB.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZWH.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZWU.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed
# /Users/armandoordoricadelatorre/Portfolio_Optimization_2023/Stocks.py:65: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.ticker, start=self.start_dt, end=self.end_dt)
# ZXM.TO
# data from alpaca
# Data from alpaca not available, pulling from yahoo. Reason: list index out of range
# [*********************100%***********************]  1 of 1 completed

# %%
pd.concat(dataframes_list).to_parquet("ETFs_data.parquet.gzip", compression='gzip')

# %%
df = pd.read_parquet("ETFs_data.parquet.gzip")

# %%
successfully_pulled_stocks = set(df['Stock_name'])
success_rate = len(successfully_pulled_stocks)/len(canadian_etfs_parsed)
success_rate
# Out:
# 1.0

# %%
failed_pulls = list(set(canadian_etfs_parsed) - set(successfully_pulled_stocks))
failed_pulls

failed_pulls_dataframes_list = []

for x in failed_pulls: 
    print(x)
    
    temp_data = Stock(x, '2018-03-01', '2023-03-01').ticker_data
    temp_data['Stock_name'] = x
    failed_pulls_dataframes_list.append(temp_data)

# %%
successfully_pulled_stocks = list(successfully_pulled_stocks)
successfully_pulled_stocks.sort()
for x in successfully_pulled_stocks: 
    print('- '+x)
# Out:
# - BXF.TO
# - CBD.TO
# - CBH.TO
# - CBN.TO
# - CBO.TO
# - CDZ.TO
# - CEW.TO
# - CGL.TO
# - CGR.TO
# - CHB.TO
# - CIF.TO
# - CLF.TO
# - CLG.TO
# - CMR.TO
# - COW.TO
# - CPD.TO
# - CSD.TO
# - CUD.TO
# - CVD.TO
# - CWW.TO
# - CXF.TO
# - CYH.TO
# - DLR.TO
# - DXM.TO
# - ELV.TO
# - ETP.TO
# - EUR.TO
# - FDE.TO
# - FDV.TO
# - FDY.TO
# - FHB.TO
# - FHC.TO
# - FHD.TO
# - FHE.TO
# - FHF.TO
# - FHG.TO
# - FHH.TO
# - FHM.TO
# - FHQ.TO
# - FHU.TO
# - FIE.TO
# - FLI.TO
# - FSL.TO
# - FUD.TO
# - FXM.TO
# - HAB.TO
# - HAC.TO
# - HAD.TO
# - HAF.TO
# - HAJ.TO
# - HAL.TO
# - HAZ.TO
# - HBA.TO
# - HBB.TO
# - HBD.TO
# - HBU.TO
# - HCA.TO
# - HEA.TO
# - HED.TO
# - HEE.TO
# - HEF.TO
# - HEJ.TO
# - HEP.TO
# - HEU.TO
# - HEW.TO
# - HEX.TO
# - HFD.TO
# - HFG.TO
# - HFP.TO
# - HFR.TO
# - HFT.TO
# - HFU.TO
# - HGD.TO
# - HGU.TO
# - HGY.TO
# - HHF.TO
# - HIU.TO
# - HIX.TO
# - HMF.TO
# - HND.TO
# - HNU.TO
# - HNY.TO
# - HOD.TO
# - HOG.TO
# - HOU.TO
# - HPR.TO
# - HQD.TO
# - HQU.TO
# - HSD.TO
# - HSL.TO
# - HSU.TO
# - HUC.TO
# - HUF.TO
# - HUG.TO
# - HUM.TO
# - HUN.TO
# - HUT.TO
# - HUV.TO
# - HUZ.TO
# - HVI.TO
# - HVU.TO
# - HXD.TO
# - HXE.TO
# - HXF.TO
# - HXS.TO
# - HXT.TO
# - HXU.TO
# - HYI.TO
# - HZD.TO
# - HZU.TO
# - ILV.TO
# - KILO.TO
# - MXF.TO
# - PBD.TO
# - PBI.TO
# - PDC.TO
# - PDF.TO
# - PFL.TO
# - PHE.TO
# - PHR.TO
# - PIN.TO
# - PMM.TO
# - PPS.TO
# - PRA.TO
# - PSA.TO
# - PSB.TO
# - PTB.TO
# - PUD.TO
# - PXC.TO
# - QCD.TO
# - QEM.TO
# - QGL.TO
# - QIE.TO
# - QMA.TO
# - QMY.TO
# - QQC.TO
# - QUS.TO
# - QXM.TO
# - RBO.TO
# - RCD.TO
# - RID.TO
# - RIT.TO
# - RPD.TO
# - RQF.TO
# - RQH.TO
# - RQI.TO
# - RUD.TO
# - RWC.TO
# - RWE.TO
# - RWU.TO
# - RWW.TO
# - RXD.TO
# - SVR.TO
# - TLV.TO
# - TXF.TO
# - ULV.TO
# - USB.TO
# - UXM.TO
# - VA.TO
# - VAB.TO
# - VBG.TO
# - VBU.TO
# - VCE.TO
# - VCN.TO
# - VDU.TO
# - VDY.TO
# - VE.TO
# - VEE.TO
# - VEF.TO
# - VFV.TO
# - VGG.TO
# - VGH.TO
# - VRE.TO
# - VSB.TO
# - VSC.TO
# - VSP.TO
# - VUN.TO
# - VUS.TO
# - VXC.TO
# - VXM.TO
# - WXM.TO
# - XBB.TO
# - XBM.TO
# - XCB.TO
# - XCD.TO
# - XCG.TO
# - XCS.TO
# - XCV.TO
# - XDV.TO
# - XEB.TO
# - XEC.TO
# - XEF.TO
# - XEG.TO
# - XEH.TO
# - XEI.TO
# - XEM.TO
# - XEN.TO
# - XEU.TO
# - XFN.TO
# - XFR.TO
# - XGB.TO
# - XGD.TO
# - XGI.TO
# - XHC.TO
# - XHD.TO
# - XIC.TO
# - XIN.TO
# - XIT.TO
# - XIU.TO
# - XLB.TO
# - XMA.TO
# - XMD.TO
# - XMI.TO
# - XMM.TO
# - XMU.TO
# - XMV.TO
# - XMW.TO
# - XQB.TO
# - XQQ.TO
# - XRB.TO
# - XRE.TO
# - XSB.TO
# - XSH.TO
# - XSP.TO
# - XSQ.TO
# - XST.TO
# - XSU.TO
# - XTR.TO
# - XUS.TO
# - XUT.TO
# - XWD.TO
# - XXM.TO
# - YXM.TO
# - ZAG.TO
# - ZBK.TO
# - ZCH.TO
# - ZCM.TO
# - ZCN.TO
# - ZCS.TO
# - ZDB.TO
# - ZDI.TO
# - ZDJ.TO
# - ZDM.TO
# - ZDV.TO
# - ZDY.TO
# - ZEA.TO
# - ZEB.TO
# - ZEF.TO
# - ZEM.TO
# - ZEO.TO
# - ZEQ.TO
# - ZFH.TO
# - ZFL.TO
# - ZFM.TO
# - ZFS.TO
# - ZGD.TO
# - ZGI.TO
# - ZGQ.TO
# - ZHY.TO
# - ZIC.TO
# - ZID.TO
# - ZIN.TO
# - ZJG.TO
# - ZJN.TO
# - ZJO.TO
# - ZLB.TO
# - ZLC.TO
# - ZLU.TO
# - ZMI.TO
# - ZMP.TO
# - ZMT.TO
# - ZMU.TO
# - ZPL.TO
# - ZPR.TO
# - ZPS.TO
# - ZQQ.TO
# - ZRE.TO
# - ZRR.TO
# - ZSP.TO
# - ZST.TO
# - ZSU.TO
# - ZUB.TO
# - ZUD.TO
# - ZUE.TO
# - ZUH.TO
# - ZUQ.TO
# - ZUT.TO
# - ZWA.TO
# - ZWB.TO
# - ZWH.TO
# - ZWU.TO
# - ZXM.TO
